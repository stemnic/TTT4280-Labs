# %%
import os

os.system("sh sample.sh")
# Out:
# 0

# %%
from raspi_import import raspi_import

data = raspi_import("data/adcData.bin")

print(data[1])
# Out:
# [[4095 1365 2483 4095 4095]
#  [4095 4095 4095 4095 4095]
#  [4095 4095 4095 4095 4095]
#  ...
#  [4095 4095 4095 4095 4095]
#  [4095 4095 4095 4095 4095]
#  [4086 4076 4068 4059 4051]]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np

x=[0]
channel1=[]
channel2=[]
channel3=[]
channel4=[]
channel5=[]
n=0
for samples in data[1]:
    if(n!=0):
        x.append(x[n-1]+0.000032)
    channel1.append(samples[0])
    channel2.append(samples[1])
    channel3.append(samples[2])
    channel4.append(samples[3])
    channel5.append(samples[4])
    n += 1

print(len(x))
print(len(channel1))
plt.plot(x,channel1)
# Out:
# 31250
# 31250

# %%
t = np.arange(256)
sp = np.fft.fft(np.sin(t))
freq = np.fft.fftfreq(t.shape[-1])
plt.plot(freq, sp.real)
