# %%
run record_video.py recordings/osBigGains2
# Out:
# Waiting for settings to adjust
# Waiting for white balance to adjust
# Start recording to recordings/osBigGains2.h264
# Recording finished
# Pack video in MP4 container
# Files saved to: recordings/osBigGains2.h264 and recordings/osBigGains2.mp4

# %%
run read_video_and_extract_roi.py recodrings/test1.mp4 data/test1.csv
# Out:
# Could not open input file. Wrong filename, or your OpenCV package might not be built with FFMPEG support. See docstring of this Python script.

# %%
# %matplotlib inline

# %%
run pulse.py recordings/osReal1.mp4 -plot -save
# Out:
# Looping through video.
# Frame 1198/1198
# Image SNR: 14.996527434097953
# Data saved to 'recordings/osReal1.txt', fps = 40.0 frames/second
# -- Pulse --
# Red: 76.12687813021702 BPM
# Green: 0.0 BPM
# Blue: 40.066777963272116 BPM
# -- Pulse SNR --
# Red: 16.53022348158204 (old: 3.7920024258544203)
# Green: 0 (old: 0)
# Blue: 11.312468592767017 (old: 3.5610155155065932)
# -- Conclusion --
# Based on signal-to-noise ratio, red seems to be the best estimate, with 76.12687813021702 BPM.
# Done

# %%
run pulse.py recordings/osReal2.mp4 -plot -save
# Out:
# Looping through video.
# Frame 1198/1198
# Image SNR: 14.465744179929098
# Data saved to 'recordings/osReal2.txt', fps = 40.0 frames/second
# -- Pulse --
# Red: 72.12020033388983 BPM
# Green: 0.0 BPM
# Blue: 58.09682804674458 BPM
# -- Pulse SNR --
# Red: 22.462460520297228 (old: 3.9558130556423223)
# Green: 0 (old: 0)
# Blue: 13.677837897789866 (old: 3.4060826014161796)
# -- Conclusion --
# Based on signal-to-noise ratio, red seems to be the best estimate, with 72.12020033388983 BPM.
# Done

# %%
run pulse.py recordings/osReal3.mp4 -plot -save
# Out:
# Looping through video.
# Frame 1198/1198
# Image SNR: 15.051309064014333
# Data saved to 'recordings/osReal3.txt', fps = 40.0 frames/second
# -- Pulse --
# Red: 72.12020033388983 BPM
# Green: 0.0 BPM
# Blue: 70.11686143572621 BPM
# -- Pulse SNR --
# Red: 44.49808445582905 (old: 3.7786556424982285)
# Green: 0 (old: 0)
# Blue: 31.388076171774035 (old: 3.3905297932544123)
# -- Conclusion --
# Based on signal-to-noise ratio, red seems to be the best estimate, with 72.12020033388983 BPM.
# Done

# %%
run pulse.py recordings/osReal4.mp4 -plot -save
# Out:
# Looping through video.
# Frame 1198/1198
# Image SNR: 15.049148500618147
# Data saved to 'recordings/osReal4.txt', fps = 40.0 frames/second
# -- Pulse --
# Red: 68.11352253756262 BPM
# Green: 0.0 BPM
# Blue: 68.11352253756262 BPM
# -- Pulse SNR --
# Red: 33.09955586610728 (old: 3.557311150243451)
# Green: 0 (old: 0)
# Blue: 15.048636181823033 (old: 3.4251149604922397)
# -- Conclusion --
# Based on signal-to-noise ratio, red seems to be the best estimate, with 68.11352253756262 BPM.
# Done

# %%
run pulse.py recordings/osReal5.mp4 -plot -save
# Out:
# Looping through video.
# Frame 1198/1198
# Image SNR: 14.02171842713069
# Data saved to 'recordings/osReal5.txt', fps = 40.0 frames/second
# -- Pulse --
# Red: 70.11686143572621 BPM
# Green: 0.0 BPM
# Blue: 70.11686143572621 BPM
# -- Pulse SNR --
# Red: 58.17806424690428 (old: 3.7059404887450156)
# Green: 0 (old: 0)
# Blue: 35.257193057705436 (old: 3.429879453817962)
# -- Conclusion --
# Based on signal-to-noise ratio, red seems to be the best estimate, with 70.11686143572621 BPM.
# Done

# %%
run pulse.py recordings/reflectionTest.mp4 -plot -save
# Out:
# Looping through video.
# Frame 1198/1198
# Image SNR: 27.23418860935387
# Data saved to 'recordings/reflectionTest.txt', fps = 40.0 frames/second
# -- Pulse --
# Red: 34.05676126878131 BPM
# Green: 34.05676126878131 BPM
# Blue: 44.07345575959933 BPM
# -- Pulse SNR --
# Red: 17.07571737971378 (old: 4.197043120356629)
# Green: 18.75799004833938 (old: 4.368197799508033)
# Blue: 16.708124326759215 (old: 4.263947917391586)
# -- Conclusion --
# Based on signal-to-noise ratio, green seems to be the best estimate, with 34.05676126878131 BPM.
# Done

# %%
run pulse.py recordings/osRealOffset.mp4 -plot -save
# Out:
# Looping through video.
# Frame 1198/1198
# Image SNR: 11.039553890035602
# Data saved to 'recordings/osRealOffset.txt', fps = 40.0 frames/second
# -- Pulse --
# Red: 68.11352253756262 BPM
# Green: 40.066777963272116 BPM
# Blue: 42.07011686143572 BPM
# -- Pulse SNR --
# Red: 11.156946066463426 (old: 3.2026893083972525)
# Green: 10.556747021441932 (old: 3.9527373596481326)
# Blue: 8.900231322676948 (old: 3.0175227229013353)
# -- Conclusion --
# Based on signal-to-noise ratio, red seems to be the best estimate, with 68.11352253756262 BPM.
# Done

# %%
run pulse.py recordings/osRealOffset2.mp4 -plot -save
# Out:
# Looping through video.
# Frame 1198/1198
# Image SNR: 0.5399444383496246
# Data saved to 'recordings/osRealOffset2.txt', fps = 40.0 frames/second
# -- Pulse --
# Red: 34.05676126878131 BPM
# Green: 0.0 BPM
# Blue: 0.0 BPM
# -- Pulse SNR --
# Red: 28.921086191179768 (old: 4.4144357656119695)
# Green: 0 (old: 0)
# Blue: 0 (old: 0)
# -- Conclusion --
# Based on signal-to-noise ratio, red seems to be the best estimate, with 34.05676126878131 BPM.
# Done

# %%
run pulse.py recordings/osBigGains1.mp4 -plot -save
# Out:
# Looping through video.
# Frame 1198/1198
# Image SNR: 25.014685249736505
# Data saved to 'recordings/osBigGains1.txt', fps = 40.0 frames/second
# -- Pulse --
# Red: 108.18030050083472 BPM
# Green: 108.18030050083472 BPM
# Blue: 108.18030050083472 BPM
# -- Pulse SNR --
# Red: 22.805366322601653 (old: 3.3598179563924098)
# Green: 45.77992908262871 (old: 2.895178558106452)
# Blue: 18.573739324735037 (old: 3.1259602509093285)
# -- Conclusion --
# Based on signal-to-noise ratio, green seems to be the best estimate, with 108.18030050083472 BPM.
# Done

# %%
run pulse.py recordings/osBigGains2.mp4 -plot -save
# Out:
# Looping through video.
# Frame 1198/1198
# Image SNR: 33.100189188478744
# Data saved to 'recordings/osBigGains2.txt', fps = 40.0 frames/second
# -- Pulse --
# Red: 94.1569282136895 BPM
# Green: 94.1569282136895 BPM
# Blue: 94.1569282136895 BPM
# -- Pulse SNR --
# Red: 17.522224303423577 (old: 3.8715282535059212)
# Green: 29.651019419410282 (old: 3.5764453508490335)
# Blue: 21.469447092604717 (old: 3.229973389983712)
# -- Conclusion --
# Based on signal-to-noise ratio, green seems to be the best estimate, with 94.1569282136895 BPM.
# Done
