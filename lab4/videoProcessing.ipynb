# %%
run record_video.py recordings/isak1
# Out:
# Waiting for settings to adjust
# Waiting for white balance to adjust
# Start recording to recordings/isak1.h264
# Recording finished
# Pack video in MP4 container
# Files saved to: recordings/isak1.h264 and recordings/isak1.mp4

# %%
run read_video_and_extract_roi.py recodrings/test1.mp4 data/test1.csv
# Out:
# Could not open input file. Wrong filename, or your OpenCV package might not be built with FFMPEG support. See docstring of this Python script.

# %%
# %matplotlib inline

# %%
run pulse.py recordings/test1.mp4 -plot
# Out:
# Looping through video.
# Frame 1198/1198
# Image SNR: 31.30805105089097
# -- Pulse --
# Red: 66.110183639399 BPM
# Green: 66.110183639399 BPM
# Blue: 64.10684474123539 BPM
# -- Pulse SNR --
# Red: 37.75089054835656 (old: 4.043704943104851)
# Green: 32.084392336413195 (old: 3.7617023763192203)
# Blue: 31.92611881428319 (old: 3.5683486072002464)
# -- Conclusion --
# Based on signal-to-noise ratio, red seems to be the best estimate, with 66.110183639399 BPM.
# Done
